# %%
t = 'ci.(lkfdsaj)'
print(t[4:-1])
# Out:
# lkfdsaj

# %%
t = ['c1.(c3,c4,c5)', 'c2.(c3,c4,c5)', 'c3.(c4,c5)']
o = ''
for i in t:
    f = i[:2]
    s = i[4:-1]
    for j in s.split(','):
        o += f'{f}.{j},'
print(o)
# Out:
# c1.c3,c1.c4,c1.c5,c2.c3,c2.c4,c2.c5,c3.c4,c3.c5,
