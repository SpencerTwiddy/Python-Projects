# %%
new = '`GDP`, `Growth`, `Population`, `PerCapita`, `Share`'.split(', ')

# %%
old = '`GDP (nominal,2017)`, `GDP  growth`, `Population (2017)`, `GDP  per capita`, `Share of World GDP`'.split(', ')
print(old)
# Out:
# ['`GDP (nominal,2017)`', '`GDP  growth`', '`Population (2017)`', '`GDP  per capita`', '`Share of World GDP`']

# %%
new[0]
# Out:
# '`'

# %%
outp = ''
for i, v in enumerate(old):
    print(new[i])
    print(v)
    outp += f'{new[i]} = {v}'
    if i < len(old) - 1:
        outp += ', '
print(outp)
# Out:
# `GDP`
# `GDP (nominal,2017)`
# `Growth`
# `GDP  growth`
# `Population`
# `Population (2017)`
# `PerCapita`
# `GDP  per capita`
# `Share`
# `Share of World GDP`
# `GDP` = `GDP (nominal,2017)`, `Growth` = `GDP  growth`, `Population` = `Population (2017)`, `PerCapita` = `GDP  per capita`, `Share` = `Share of World GDP`
