# %%
import csv

# %%
file = open('Vocab_Data.csv')
csvreader = csv.reader(file)
header = []
header = next(csvreader)
rows = []
for row in csvreader:
    rows.append(row)
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 file = open('Vocab_Data.csv')
#       2 csvreader = csv.reader(file)
#       3 header = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Vocab_Data.csv'

# %%
header
rows
