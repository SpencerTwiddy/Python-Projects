# %%
import random

# %%
import random
n = 10 ** 7
p = 209
s = 0
t = 7
f = 2

for i in range(n):
    c = 0
    for j in range(t):
        if random.randint(1,209) == 1:
            c += 1
    if c > f - 1:
        s += 1
print(f"successes: {s}\nattempts: {n}\nprobability: {s/n}")
# successes: 4730
# attempts: 10000000
# probability: 0.000473
# Out:
# successes: 4730
# attempts: 10000000
# probability: 0.000473
